# %% [markdown]
# <a href="https://colab.research.google.com/github/cbvreis/storytelling-Cassio/blob/master/storytelling-colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Como tudo começou...

# %% [markdown]
# ###### Meus pais decidiram presentear seu único filho (até o momento) com um irmãozinho, e no dia 04 de novembro do ano de 1991, na cidade de Entre Rios de Minas, mais precisamente nesse local tudo começou...

# %%
image_filename = "map_hcc.png"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
    plot_bgcolor='white',
    title = 'Local de Nascimento: Hospital Cassiano Campolina - Entre Rios de Minas',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="f1345963-8de8-47dd-9f2c-e1c59edba0b4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f1345963-8de8-47dd-9f2c-e1c59edba0b4")) {
#                     Plotly.newPlot(
#                         'f1345963-8de8-47dd-9f2c-e1c59edba0b4',
#                         [],
# ...

# %% [markdown]
# ###### Papai e mamãe me deram o nome de Cássio Henrique Resende Reis, foi um momento muito especial na minha família. Minha mãe (Sandra) foi a responsável pelo nome

# %%
image_filename = "mae_nascimento.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
       plot_bgcolor='white',
    title = 'Essa moça da foto é minha mãe, a minha maior referência de amor e esse ser pequeno ao lado dela sou eu',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d0fca937-3f52-48c1-8766-78caff4a8712" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d0fca937-3f52-48c1-8766-78caff4a8712")) {
#                     Plotly.newPlot(
#                         'd0fca937-3f52-48c1-8766-78caff4a8712',
#                         [],
# ...

# %% [markdown]
# ###### Tem foto do papai também, nesse dia eu machuquei a ponta do nariz rsrs

# %%
image_filename = "pai_foto.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
       plot_bgcolor='white',
    title = 'Daniel, meu pai, meu herói, uma das melhores pessoas que alguém pode conhecer',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2c19acec-10a4-45f9-bccd-ba6e85375543" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2c19acec-10a4-45f9-bccd-ba6e85375543")) {
#                     Plotly.newPlot(
#                         '2c19acec-10a4-45f9-bccd-ba6e85375543',
#                         [],
# ...

# %% [markdown]
# ###### E meu irmão(Caio, travamos muitos duelos e batalhas nos vídeogames, partidas de futebol e até corrida de rua rsrs

# %%
image_filename = "caio.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Caio, você sabe que eu sou um grande presente na sua vida né? ',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0da219c6-77cd-43d0-8e58-c38c3f83a24a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0da219c6-77cd-43d0-8e58-c38c3f83a24a")) {
#                     Plotly.newPlot(
#                         '0da219c6-77cd-43d0-8e58-c38c3f83a24a',
#                         [],
# ...

# %% [markdown]
# ###### Na minha infância eu praticava algumas atividades, abaixo eu trago um pouco mais sobre cada uma

# %%
hobbys_kids = {
    'Atividade': ['Videogame','Futebol', 'Natação', 'Leitura', 'Escola'],
    'Tempo_Gasto' : [25,15,20,15,35],
    'Habilidade' : [7,1,8,7,9]
}
fig = px.bar(hobbys_kids, x =hobbys_kids['Atividade'] , y =hobbys_kids['Tempo_Gasto'],labels={'x':'Atividade', 'y' : 'Tempo gasto em %'})
fig.update_traces(marker_color='rgb(128,128,128)', marker_line_color='rgb(105,105,105)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Tempo gasto em meus principais hobbies')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8eac3818-33e0-451b-a57a-54bbd675097f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8eac3818-33e0-451b-a57a-54bbd675097f")) {
#                     Plotly.newPlot(
#                         '8eac3818-33e0-451b-a57a-54bbd675097f',
# ...

# %% [markdown]
# ###### Mas futebol nunca foi meu forte, minhas skills em cada uma

# %%
fig = px.bar(hobbys_kids, x =hobbys_kids['Atividade'] , y =hobbys_kids['Habilidade'],labels={'x':'Atividade', 'y' : 'Habilidade em cada Hobbie'})
fig.update_traces(marker_color='rgb(13, 84, 110)', marker_line_color='rgb(13, 17, 110)',
                  marker_line_width=1.5)
fig.update_layout(title_text='Habilidade em cada hobbie',  plot_bgcolor='white')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6add8684-51e0-43ba-bfe9-7dabcac2d762" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6add8684-51e0-43ba-bfe9-7dabcac2d762")) {
#                     Plotly.newPlot(
#                         '6add8684-51e0-43ba-bfe9-7dabcac2d762',
# ...

# %% [markdown]
# ###### Já fui jogador

# %%
image_filename = "jogador.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Camisa 10',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="248f5398-15ea-4d55-afae-6ce147a18e4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("248f5398-15ea-4d55-afae-6ce147a18e4e")) {
#                     Plotly.newPlot(
#                         '248f5398-15ea-4d55-afae-6ce147a18e4e',
#                         [],
# ...

# %% [markdown]
# ###### Escritor

# %%
image_filename = "carlos_drummond.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
       plot_bgcolor='white',
    title = 'Referência ao grande Carlos Drummond',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1f77fc29-bbc9-4b35-b0c0-2697d9d88ce2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1f77fc29-bbc9-4b35-b0c0-2697d9d88ce2")) {
#                     Plotly.newPlot(
#                         '1f77fc29-bbc9-4b35-b0c0-2697d9d88ce2',
#                         [],
# ...

# %% [markdown]
# ###### Nadador

# %%
image_filename = "nadador.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Bons tempos nas raias do clube de Entre Rios',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cb039005-17c7-4570-a60b-96673fee9639" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb039005-17c7-4570-a60b-96673fee9639")) {
#                     Plotly.newPlot(
#                         'cb039005-17c7-4570-a60b-96673fee9639',
#                         [],
# ...

# %% [markdown]
# ###### Pirata

# %%
image_filename = "pirata.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Jack Sparrow',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="efef9ada-4d20-4028-8525-820653c0fa2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("efef9ada-4d20-4028-8525-820653c0fa2c")) {
#                     Plotly.newPlot(
#                         'efef9ada-4d20-4028-8525-820653c0fa2c',
#                         [],
# ...

# %% [markdown]
# ###### Fazendeiro

# %%
image_filename = "fazendeiro.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Já pensando nas criações de gado',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5d6e36ea-6370-48eb-aa27-58995cd55454" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d6e36ea-6370-48eb-aa27-58995cd55454")) {
#                     Plotly.newPlot(
#                         '5d6e36ea-6370-48eb-aa27-58995cd55454',
#                         [],
# ...

# %% [markdown]
# ###### Dom pedro, essa ficou legal rsrs, valeu mãe.

# %%
image_filename = "dom_pedro.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
    plot_bgcolor='white',
    title = 'Melhor fantasia no 7 de setembro',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="7ac05208-876b-479e-8f16-e28740fb1dcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("7ac05208-876b-479e-8f16-e28740fb1dcb")) {
#                     Plotly.newPlot(
#                         '7ac05208-876b-479e-8f16-e28740fb1dcb',
#                         [],
# ...

# %% [markdown]
# ### Sou uma pessoa normal, passei altos e baixos na minha vida. Acho importante passar brevemente pelos principais momentos que me abateram

# %% [markdown]
# ###### Nos anos de 2004,2006 e 2008 perdi meus dois avós maternos e meu padrinho, foi um momento de grande reflexão. No ano de 2014 eu acabei mudando de curso na faculdade, isso me gerou também um momento de preocupação.

# %% [markdown]
# ###### Mas isso foi superado por todos e hoje celebramos em cada encontro nossas vidas.

# %%
data_ano = {
    'Humor_ratting' : [78,79,75,76,77,74,78,70,74,75,76,80,81,45,75,48,78,77,45,75,80,86,92,93,94,95,97,98,99],
    'Ano' : np.arange(start=1991, stop=2020, step=1)
}
fig = px.line(data_ano, x=data_ano['Ano'], y = data_ano['Humor_ratting'],labels={'x':'Anos', 'y' : 'Nota'})
fig.update_layout(title_text='Picos e Vales ao longo da minha vida',plot_bgcolor='white')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0c62d045-70f3-495c-a385-54f74129172a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0c62d045-70f3-495c-a385-54f74129172a")) {
#                     Plotly.newPlot(
#                         '0c62d045-70f3-495c-a385-54f74129172a',
# ...

# %% [markdown]
# ### Algumas palavras guias

# %%
comment_words = "Dedicação, suor, suor, trabalho, trabalho, repetição, treino,  esforço, humildade, resultado, resultado, resultado, humildade, esforço, tempo, estudo, estudo, business intelligence, inteligência, família, futuro, familia, amigos, capacidade, técnica, técnica, decisão, resiliência, resilência, entendimento, casamento, trends, sistemas, datascience, dados, análise, metodologia, técnica, estátistica, metodologia "
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='white', 
                min_font_size = 10).generate(comment_words) 
                    
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %% [markdown]
# ## Pausa pro momento fofura, essa é a Cecília, minha sobrinha e afilhada que veio para alegrar nossas vidas

# %%
image_filename = "cecilia.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
    plot_bgcolor='white',
    title = 'Garotinha mais linda <3',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="5d644aa5-33c1-437a-8bf5-cb5e8ce210f0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5d644aa5-33c1-437a-8bf5-cb5e8ce210f0")) {
#                     Plotly.newPlot(
#                         '5d644aa5-33c1-437a-8bf5-cb5e8ce210f0',
#                         [],
# ...

# %% [markdown]
# ### Preciso falar dela também, que além de namorada é uma grande parceira da minha vida, ela abriu as portas do mundo pra mim

# %%
image_filename = "carol.jpeg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
    plot_bgcolor='white',
    title = 'Sem palavras ...',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="be1a5e05-d2f9-443a-85ec-307d26794b68" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("be1a5e05-d2f9-443a-85ec-307d26794b68")) {
#                     Plotly.newPlot(
#                         'be1a5e05-d2f9-443a-85ec-307d26794b68',
#                         [],
# ...

# %%
fig = go.Figure(data=go.Scattergeo(
    
    lat = [-19.6248, 40.4781,48.8589,51.5076,52.3547,41.3925,41.40,-32.0967361,-33.4377968,41.29122181,45.4542119,43.7698712,41.8933203,-23.5506507,-4.4072988],
    lon = [-43.9663, -3.7034,2.3469,-0.1276,4.9040,2.1404,2.1740,-64.03793335,-70.6504451,-8.94,9.11135096,11.2555757,12.482,-46.6333824,-37.7836307],
    #name= ['Belo Horizonte','Madrid','Paris','Londres','Amsterdam'],
    mode = 'lines',
    line = dict(width = 4, color = 'red'),
))

fig.update_layout(
    title_text = 'Nossas viagens juntos',
    showlegend = False,
    geo = dict(
        resolution = 50,
        showland = True,
        showlakes = True,
        landcolor = 'rgb(204, 204, 204)',
        countrycolor = 'rgb(204, 204, 204)',
        lakecolor = 'rgb(255, 255, 255)',
        projection_type = "equirectangular",
        coastlinewidth = 2,
        lataxis = dict(
            range = [-45, 80],
            showgrid = True,
            dtick = 10
        ),
        lonaxis = dict(
            range = [-150, 40],
            showgrid = True,
            dtick = 20
        ),
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8853e27d-f713-428e-8196-cbb49662df33" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8853e27d-f713-428e-8196-cbb49662df33")) {
#                     Plotly.newPlot(
#                         '8853e27d-f713-428e-8196-cbb49662df33',
# ...

# %% [markdown]
# ### Fazendo o juramento sozinho porque eu fui o único formando no curso de sistemas de informação aqui na UFJF. Rsrsrs

# %%
image_filename = "cassio.jpg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
    plot_bgcolor='white',
    title = 'Dia muito importante',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cd7e378e-c5d9-420c-82a7-6b0f2007bc2c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cd7e378e-c5d9-420c-82a7-6b0f2007bc2c")) {
#                     Plotly.newPlot(
#                         'cd7e378e-c5d9-420c-82a7-6b0f2007bc2c',
#                         [],
# ...

# %% [markdown]
# ##  Meus assuntos de interesse no momento

# %%
data_skills = {
        'Nota' : [15,13,10,11,6,9],
        'Direction' : ["N","S","E","W","NE","SE"],
        'Color' : ['Business Intelligence', 'Big data', 'Data Science', 'SQL', 'PHP','Python']
    
}
df = pd.DataFrame(data_skills)
fig = px.pie(df, values='Nota', names='Color', color_discrete_sequence=px.colors.sequential.Purples)
fig.update_layout(title_text='Tendências que eu tenho dedicado mais tempo em pesquisas')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="479418e8-7b10-45ce-9cff-d7d6feb2c3af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("479418e8-7b10-45ce-9cff-d7d6feb2c3af")) {
#                     Plotly.newPlot(
#                         '479418e8-7b10-45ce-9cff-d7d6feb2c3af',
# ...

# %%
rendimentos_faculdade=['Rendimento', 'Potencial de Conhecimento']

fig = go.Figure(data=[
    go.Bar(name='Graduação', x=rendimentos_faculdade, y=[78, 85],marker_color='rgb(160, 160, 160)', marker_line_color='rgb(13, 17, 105)'),
    go.Bar(name='Mestrado', x=rendimentos_faculdade, y=[100, 95],marker_color='rgb(153, 153, 222)', marker_line_color='rgb(153,153, 115)',),
    go.Bar(name='Pós', x=rendimentos_faculdade, y=[95, 90],marker_color='rgb(9, 9, 90)', marker_line_color='rgb(13, 105, 125)',)
])
# Change the bar mode
fig.update_layout(barmode='group',
                 title_text='Minhas considerações acadêmicas')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="6927b831-fff5-453c-b717-8439ebcaa472" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("6927b831-fff5-453c-b717-8439ebcaa472")) {
#                     Plotly.newPlot(
#                         '6927b831-fff5-453c-b717-8439ebcaa472',
# ...

# %% [markdown]
# # Programa de Reconhecimento - Categoria Inteligência - Forecast de Séries temporais

# %%
image_filename = "reconhecimento.jpg"
encoded_image = base64.b64encode(open(image_filename, 'rb').read())
img = 'data:image/png;base64,{}'.format(encoded_image.decode())

layout = go.Layout(
    images=[go.layout.Image(
        source=img, 
        sizex=1, sizey=1, 
        yanchor="bottom"
    )],
      plot_bgcolor='white',
    title = 'Pessoal da unidade de Juiz de Fora (Dez/2019)',
    xaxis = go.XAxis(
        showticklabels=False),
    yaxis = go.YAxis(
        showticklabels=False),
  
)
    
fig = go.Figure(layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="83898ff3-1a16-4ca8-88ec-2c6d4f3664e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("83898ff3-1a16-4ca8-88ec-2c6d4f3664e1")) {
#                     Plotly.newPlot(
#                         '83898ff3-1a16-4ca8-88ec-2c6d4f3664e1',
#                         [],
# ...

# %%
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.pyplot as plt
from skimage import io
import warnings
import plotly.graph_objects as go
import base64
warnings.filterwarnings("ignore")
from wordcloud import WordCloud, STOPWORDS
